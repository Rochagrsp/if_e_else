# %% [markdown]
# <a href="https://colab.research.google.com/github/Rochagrsp/if_e_else/blob/main/if_e_else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# atividade 01

# %%
pagamento =input("método de pagamento ")
if pagamento== "cartão":
  print("processando pagamento no cartão")
elif pagamento== "boleto":
  print("processando pagamento no boleto")
else:
  print("Método de pagamaento não reconhecido.")
# Out:
# método de pagamento ghg
# Método de pagamaento não reconhecido.

# %% [markdown]
# atividade 02

# %%
idade=int(input("Dgite sua idade"))
if idade<13:
  print("criança")
elif idade<18:
  print("adolescente")
elif idade<60:
  print("adulto")
else:
  print("idoso")
# Out:
# Dgite sua idade12
# criança

# %% [markdown]
# atividade 03

# %%
entrega=input("Digite o tipo de entrega ")
if entrega=="padrão":
  print("entrega padão:R$10,00")
elif entrega== "expresso":
  print("Entrega expresso:R$20,00")
elif entrega== "sedex":
  print("entrega sedex:R$30,00")
else:
  print("Opção de entrega inválida")
